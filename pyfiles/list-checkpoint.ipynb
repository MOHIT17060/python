# %%
#list
l=[]
print(l)
print(type(l))
# Out:
# []
# <class 'list'>

# %%
l=[10,20,30,"hello",10.5]
print(l)
print(type(l))
print(l[0])  #indexed
l[0]=1000
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5]
# <class 'list'>
# 10
# [1000, 20, 30, 'hello', 10.5]

# %%
# indexing and slicing
l=[10,20,30,"hello",10.5,1000,200,300,100]
print(l[3])
print(l[3][1])
print(l[-3])
print(l[ : :-1])
print(l[ : : ])
print(l[ :6:2])
# Out:
# hello
# e
# 200
# [100, 300, 200, 1000, 10.5, 'hello', 30, 20, 10]
# [10, 20, 30, 'hello', 10.5, 1000, 200, 300, 100]
# [10, 30, 10.5]

# %%
#iteratiion
l=[10,20,30,"hello",1000,10.5,77]
for i in l:
    print(i)
# Out:
# 10
# 20
# 30
# hello
# 1000
# 10.5
# 77

# %%
#indirect iteration
l=[10,20,30,"hello",1000,10.5,77]
for i in range(len(l)):
    print(l[i])
# Out:
# 10
# 20
# 30
# hello
# 1000
# 10.5
# 77

# %%
#function

# %%
## METHOD
# add element to an exixting list
# append
# listobj.append(value/obj)
# append method add new element at last position
l=[10,20,30,"hello",10.5]
l.append(1000)
print(l)

# %%
l=[10,2030,"hello",10.5]
l.append([100,200,300])
print(l)
# Out:
# [10, 2030, 'hello', 10.5, [100, 200, 300]]

# %%
l=[]
for i in range(2,11,2):
    n=i*i
    l.append(n)
print(l)
# Out:
# [4, 16, 36, 64, 100]

# %%
l=[100,23,34,11,17,32,35,98,12,7]
l1=[]
l2=[]
for i in l:
    if i%2==0:
        l1.append(i)
    else:
        l2.append(i)
print(l1)
print(l2)
# Out:
# [100, 34, 32, 98, 12]
# [23, 11, 17, 35, 7]

# %%
l=[]
for i in range(0,8,2):
    l.append(chr(65+i))
print(l)
# Out:
# ['A', 'C', 'E', 'G']

# %%
l=[10,20,30,40,[100,200,300,"decode"],1000,2000]
l1=["delhi","mumbai"]
for i in l1:
    l[4].append(i)
print(l)
# Out:
# [10, 20, 30, 40, [100, 200, 300, 'decode', 'delhi', 'mumbai'], 1000, 2000]

# %%
l=[10,20,30,40,[100,200,300,"decode"],1000,2000]
l1=["delhi","mumbai"]
for i in range(2):
    l[4].append(l1[i])
print(l)
# Out:
# [10, 20, 30, 40, [100, 200, 300, 'decode', 'delhi', 'mumbai'], 1000, 2000]

# %%
l=[100,23,34,11,17,32,35,98,12,7]
k=[0,2,5,9]

# %%
#INSERT
l=[10,20,30,"hello",10.5]
l.insert(2,"decode")
print(l)
# Out:
# [10, 20, 'decode', 30, 'hello', 10.5]

# %%
#EXTEND
l=[10,20,30,"hello",10.5]
l.extend([100])
print(l)
[10,20,30,"hello",10.5,100]
l.extend("decode")
print(l)
# Out:
# [10, 20, 30, 'hello', 10.5, 100]
# [10, 20, 30, 'hello', 10.5, 100, 'd', 'e', 'c', 'o', 'd', 'e']

# %%
l=[10,20,30,[1000,2000,["a","b"],3000,10.5,1100],"decode"]
l1=["delhi","mumbai"]
for i in l1:
    l[3][2].append(i)
print(l)
# Out:
# [10, 20, 30, [1000, 2000, ['a', 'b', 'delhi', 'mumbai'], 3000, 10.5, 1100], 'decode']

# %%
l=[10,20,30,[1000,2000,["a","b"],3000,10.5,1100],"decode"]
l1=["delhi","mumbai"]
for i in l1:
    l[3][2].insert(3,i)
print(l)
# Out:
# [10, 20, 30, [1000, 2000, ['a', 'b', 'delhi', 'mumbai'], 3000, 10.5, 1100], 'decode']

# %%
l=[10,20,30,[1000,2000,["a","b"],3000,10.5,1100],"decode"]
l1=["delhi","mumbai"]
l[3][2].extend(l1)
print(l)
# Out:
# [10, 20, 30, [1000, 2000, ['a', 'b', 'delhi', 'mumbai'], 3000, 10.5, 1100], 'decode']

# %%
l=["naman","decode","nitin","bhopal","data","madam"]
l1=[]
for i in l:
    rev=""
    for j in i:
        rev=j+rev
    if i==rev:
        l1.append(i)
print(l1)
# Out:
# ['naman', 'nitin', 'madam']

# %%
l=["naman","decode","nitin","bhopal","data","madam"]
l1=[]
for i in l:
    if i==i[ : :-1]:
        l1.append(i)
print(l1)
# Out:
# ['naman', 'nitin', 'madam']

# %%
#pop

l=[10,20,30,"hello",10.5,"decode",1000]
l1=[]
p=l.pop()
print(l)
l1.append(p)
print(l1)
# Out:
# [10, 20, 30, 'hello', 10.5, 'decode']
# [1000]
# 1000

# %%
#del is a keyword

# %%
#REMOVE
l=[10,20,30,"hello",10.5,"decode",1000]
l.remove("hello")
print(l)
# Out:
# [10, 20, 30, 10.5, 'decode', 1000]

# %%
#clear
l=[10,20,30,"hello",10.5,"decode",1000]
l.clear()
print(l)
# Out:
# []

# %%
#INDEX
#listobj.index(value,[start],[stop])
l=[10,20,30,"hello",10,10.5,1000,10,20,30,10,1000]
print(l.index(10))
print(l.index(10,1))
print(l.index(10,1,4))
# Out:
# 0
# 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 6
#       4 print(l.index(10))
#       5 print(l.index(10,1))
# ----> 6 print(l.index(10,1,4))
#
# ValueError: 10 is not in list

# %%
#count
#listobj.count(element)
l=[10,20,30,"hello",10,10.5,1000,10,20,30,10,1000]
print(l.count(10))
# Out:
# 4

# %%
#reverse()
l=[100,10,20,9]
for i in range(len(l)):
    for j in range(i+1,len(l)):
        l[i],l[j]=l[j],l[i]
print(l)
# Out:
# [9, 20, 10, 100]

# %%
#sort
#listobj.sort([reverse=false])
l=[100,10,20,9]
l.sort()
print(l)
# Out:
# [9, 10, 20, 100]

# %%
l=[100,10,20,9]
l.sort(reverse=True)
print(l)
# Out:
# [100, 20, 10, 9]

# %%
l=[100,10,20,9]
print(sorted(l))
# Out:
# [9, 10, 20, 100]

# %%
l=[1,12,5,7]
target=19
j=[]
for i in range(len(l)):
    for j in range(i+1,len(l)):
        if l[i]+l[j]==target:
            print(i,j)
# Out:
# 1 3
