# %%
a =int(input("enter any number :"))
a1= a%10
if a1%3==0:
    print(a,"is divisible by 3")
else:
    print(a,"is not divisible by 3")
# Out:
# enter any number : 149
# 149 is divisible by 3

# %%
a = int(input("enter any number"))
if a%2==0:
    print(a , "is an even number")
# Out:
# enter any number 14
# 14 is an even number

# %%
a=int(input("enter any number"))
if a>=18:
      print(a,"is an eligible for vote")
else:
      print(a,"is not eligible for vote")
# Out:
# enter any number 34
# 34 is an eligible for vote

# %%
sci = int(input("enter marks"))
lang=int(input("enter marks"))
math=int(input("enter marks"))

a=(sci+lang+math)//3
print(a,"this is percentage ")
if a>65:
    print("first devision")
elif a>50:
    print("second division")
elif a>33:
    print("third division")
else:
    print("fail")
# Out:
# enter marks 90
# enter marks 90
# enter marks 90
# 90 this is percentage
# first devision

# %%
a = int(input("enter number"))
if a>0:
    if a%2==0:
        print("even")
    else:
        print("odd")
elif a<0:
    print("negative number")
else:
    print("number is zero")
# Out:
# enter number 0
# number is zero

# %%
a=int(input("enter number"))
b=int(input("enter number"))
c=int(input("enter number"))
if a>=b and a>=c:
    if a<b+c:
        if a!=b and a!=c and b!=c:
            print("scalene triangle")
        elif a==b and a==c:
            print("equilateral triangle")
        else:
            print("isosceles triangle")
elif b>=a and b>=c:
    if b<a+c:
        if b!=c and b!=a and c!=a:
            print("scalene triangle")
        elif b==c and b==a:
            print("equilateral triangle")
        else:
            print("isosceles triangle")
elif c>=a and c>=b:
    if c<a+b:
        if c!=b and c!=a and b!=a:
            print("scalene triangle")
        elif c==b and c==a:
            print("equilateral triangle")
        else:
            print("isosceles triangle")
else:
    print("wrong entry")
# Out:
# enter number 70
# enter number 50
# enter number 50
# isosceles triangle

# %%
balance = int(input("enter number"))
withdraw_amount = int(input("enter number"))
if withdraw_amount<=balance:
    print("left amount",balance-withdraw_amount)
else :
    print("insufficient balance")
# Out:
# enter number 400
# enter number 500
# insufficient balance

# %%
#leap year( to check weather its a leap year or not?
year=int(input("enter any year"))
if year%4==0:
    if year%100==0:
        if year%400==0:
            print(year, " it is  a leap year")
        else: print(year, " it is not a leap year")
    else: print(year, " it is a leap year")
else:
    print(year, " it is not a leap year")

# %%
a = int(input("enter number"))
b = int(input("enter number"))
c = int(input("enter number"))
d = int(input("enter number"))
a1=a*0.3
b1=b*0.3
c1=c*0.3
d1=d*0.1
e=(a1+b1+c1+d1)
f=(a1+b1+c1+d1+5)
if d>=95:
    if f>=90:
        print("A")
    elif f>80 and f<89:
        print("B")
    elif f>70 and f<79:
        print("C")
    elif f>60 and f<69:
        print("D")
    else:
        print("F")
elif e>=90:
        print("A") 
elif e>80 and e<89:
        print("B")    
elif e>70 and e<79:
        print("C")
elif e>60 and e<69:
        print("D")
else:
    print("F")
# Out:
# enter number 90
# enter number 90
# enter number 90
# enter number 95
# A

# %%
a = int(input("enter number"))
b = int(input("enter number"))
c = int(input("enter number"))
d = int(input("enter number"))
a1=a*0.3
b1=b*0.3
c1=c*0.3
d1=d*0.1
e=(a1+b1+c1+d1)
f=(a+b+c+5)*0.9 
if d>=95:
    if f>=90:
        print("A")
    elif f>80 and f<89:
        print("B")
    elif f>70 and f<79:
        print("C")
    elif f>60 and f<69:
        print("D")
    else:
        print("F")
elif e>=90:
        print("A") 
elif e>80 and e<89:
        print("B")    
elif e>70 and e<79:
        print("C")
elif e>60 and e<69:
        print("D")
else:
    print("F")
# Out:
# enter number 100
# enter number 1000
# enter number 122
# enter number 122
# A
