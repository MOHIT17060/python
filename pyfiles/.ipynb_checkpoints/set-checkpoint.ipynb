# %%
s=set()
print(s)
# Out:
# set()

# %%
s={1,2,3,"hello"}
print(s)
print(type(s))
# Out:
# {1, 2, 3, 'hello'}
# <class 'set'>

# %%
s={1,2,3,"hello"}
print(len(s))
for i in s:
    print(i,end=" ")
# Out:
# 4
# 1 2 3 hello

# %%
s={1,2,3,"hello"}
p=s.pop()
print(s)
print(p)
# Out:
# {2, 3, 'hello'}
# 1

# %%
s={1,2,3,"hello"}
p=s.remove(3)
print(s)
# Out:
# {1, 2, 'hello'}

# %%
s={1,2,3,"hello"}
s.clear()
print(s)
# Out:
# set()

# %%
s={}
print(type(s))
# Out:
# <class 'dict'>
