# %%
#wpp that returns whwther a given number is prime or not
def prime(n):
    if n==0 or n==1:
        return false
    elif n>1:
        for i in range(2,n):
            if n%i==0:
                return false 
                break
        else:
            return true
    else:
        return false

# %%
#wpf that returns prime number between start and end take user input
def prime(s):
    if n==0 or n==1:
        return false
    elif n>1:
        for i in range(2,n):print(i,end=" "
            if n%i==0:
                return false 
                break
        else:
            return true

# %%
def prime(start,end):
    l=[]
    for i in range(start,end+1):
        for j in range(2,i):
            if i%j==0:
                break
        else:
            l.append(i)
    return l

# %%
start=int(input("number"))
end=int(input("number"))
prime(start,end)
# Out:
# number 1
# number 5
# [1, 2, 3, 5]

# %%
#wpf that return armstrong number between 1 to 2000
#wpf that returns whtere a given number is a armstrong or not 
#wpf that returns a febonachi series upto end term 
#wpf that returns enth term of fibonachi

# %%
start=int(input("number"))
end=int(input("number"))
l=[]
for i in range(start,end+1):
        for j in range(2,i):
            if i%j==0:
                break
        else:
            l.append(i)
print(l)
# Out:
# number 10
# number 20
# [11, 13, 17, 19]

# %%
start=int(input("number"))
end=int(input("number"))
for i in range(start,end+1):
        for j in range(2,i):
            if i%j==0:
                break
        else:
            print(i,"p")

# %%
num=int(input("number"))
sume=0
temp=num
a=len(str(num))
while num!=0:
    digit=num%10
    sume=sume+(digit**a)
    num=num//10
if sume==temp:
    print("arms")
else:
    print("not")
# Out:
# number 1634
# arms

# %%
def armst(num):
    sume=0
    temp=num
    a=len(str(num))
    while num!=0:
        digit=num%10
        sume=sume+(digit**a)
        num=num//10
    if sume==temp:
        return True
    else:
        return False

# %%
l=[]
for i in range(1,2000):
    if armst(i):
        l.append(i)
print(l)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9, 153, 370, 371, 407, 1634]

# %%
#wpf that returns largest among three number

# %%
#wpf to sum all the number in a list 
#[10,12,14,57]
#wpf that return whther a given string palanrom or not
#wpf to calculate the factorial of a number,the function accept number as an argument
#wpf that takes a list and retuer a new list with distint element from first list.[1,1,2,10,2,5,10,3,4]

# %%
l=[]
def suml(l):
    sum=0
    p=len(l)
    for i in  range(0,p):
        sum=sum+l[i]
    return sum    naman

# %%
l=[10,12,14,57]
suml(l)
# Out:
# 93

# %%
def panandrom(s):
    rev=""
    l=len(s)
    for i in range(0,l):
        rev=s[i]+rev
    if rev==s:
        return("palandrom")
    else:
        return("not palandrom")

# %%
def factorial(n):
    fact=1
    for i in range(1,n+1):
        fact=fact*i
    return fact

# %%
factorial(5)
# Out:
# 120
